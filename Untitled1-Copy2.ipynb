# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'svg'

import warnings
warnings.filterwarnings('ignore')
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

from imblearn.over_sampling import SMOTE
import itertools

from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier

from xgboost import XGBClassifier
#from lightgbm import LGBMClassifier
from catboost import CatBoostClassifier
from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
import joblib

# %%
new_data = pd.read_csv("/Users/sdong/phd_doc/att/credit/all_data.csv")
new_data.info()
new_data.isnull().sum().sort_values(ascending=False)
new_data=new_data.drop(['Unnamed: 0'], axis=1)
new_data.columns
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30322 entries, 0 to 30321
# Data columns (total 59 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Unnamed: 0                           30322 non-null  int64
#  1   ID                                   30322 non-null  float64
#  2   Gender                               30322 non-null  float64
#  3   Car                                  30322 non-null  float64
#  4   Reality                              30322 non-null  float64
#  5   inc                                  30322 non-null  float64
#  6   DAYS_BIRTH                           30322 non-null  float64
#  7   DAYS_EMPLOYED                        30322 non-null  float64
#  8   FLAG_MOBIL                           30322 non-null  float64
#  9   wkphone                              30322 non-null  int64
#  10  phone                                30322 non-null  int64
#  11  email                                30322 non-null  int64
#  12  famsize                              30322 non-null  int64
#  13  begin_month                          30322 non-null  float64
#  14  dep_value                            30322 non-null  object
#  15  target                               30322 non-null  int64
#  16  ChldNo_0                             30322 non-null  float64
#  17  ChldNo_1                             30322 non-null  float64
#  18  ChldNo_2More                         30322 non-null  float64
#  19  gp_inc_high                          30322 non-null  float64
#  20  gp_inc_low                           30322 non-null  float64
#  21  gp_inc_medium                        30322 non-null  float64
#  22  Age                                  30322 non-null  float64
#  23  gp_Age_high                          30322 non-null  float64
#  24  gp_Age_highest                       30322 non-null  float64
#  25  gp_Age_low                           30322 non-null  float64
#  26  gp_Age_lowest                        30322 non-null  float64
#  27  gp_Age_medium                        30322 non-null  float64
#  28  worktm                               30322 non-null  float64
#  29  gp_worktm_high                       30322 non-null  int64
#  30  gp_worktm_highest                    30322 non-null  int64
#  31  gp_worktm_low                        30322 non-null  int64
#  32  gp_worktm_lowest                     30322 non-null  int64
#  33  gp_worktm_medium                     30322 non-null  int64
#  34  famsizegp_1                          30322 non-null  int64
#  35  famsizegp_2                          30322 non-null  int64
#  36  famsizegp_3more                      30322 non-null  int64
#  37  inctp_Commercial associate           30322 non-null  int64
#  38  inctp_State servant                  30322 non-null  int64
#  39  inctp_Working                        30322 non-null  int64
#  40  occyp_Laborwk                        30322 non-null  int64
#  41  occyp_Other                          30322 non-null  int64
#  42  occyp_hightecwk                      30322 non-null  int64
#  43  occyp_officewk                       30322 non-null  int64
#  44  houtp_Co-op apartment                30322 non-null  int64
#  45  houtp_House / apartment              30322 non-null  int64
#  46  houtp_Municipal apartment            30322 non-null  int64
#  47  houtp_Office apartment               30322 non-null  int64
#  48  houtp_Rented apartment               30322 non-null  int64
#  49  houtp_With parents                   30322 non-null  int64
#  50  edutp_Higher education               30322 non-null  int64
#  51  edutp_Incomplete higher              30322 non-null  int64
#  52  edutp_Lower secondary                30322 non-null  int64
#  53  edutp_Secondary / secondary special  30322 non-null  int64
#  54  famtp_Civil marriage                 30322 non-null  int64
#  55  famtp_Married                        30322 non-null  int64
#  56  famtp_Separated                      30322 non-null  int64
#  57  famtp_Single / not married           30322 non-null  int64
#  58  famtp_Widow                          30322 non-null  int64
# dtypes: float64(22), int64(36), object(1)
# memory usage: 13.6+ MB
# Index(['ID', 'Gender', 'Car', 'Reality', 'inc', 'DAYS_BIRTH', 'DAYS_EMPLOYED',
#        'FLAG_MOBIL', 'wkphone', 'phone', 'email', 'famsize', 'begin_month',
#        'dep_value', 'target', 'ChldNo_0', 'ChldNo_1', 'ChldNo_2More',
#        'gp_inc_high', 'gp_inc_low', 'gp_inc_medium', 'Age', 'gp_Age_high',
#        'gp_Age_highest', 'gp_Age_low', 'gp_Age_lowest', 'gp_Age_medium',
#        'worktm', 'gp_worktm_high', 'gp_worktm_highest', 'gp_worktm_low',
#        'gp_worktm_lowest', 'gp_worktm_medium', 'famsizegp_1', 'famsizegp_2',
#        'famsizegp_3more', 'inctp_Commercial associate', 'inctp_State servant',
#        'inctp_Working', 'occyp_Laborwk', 'occyp_Other', 'occyp_hightecwk',
#        'occyp_officewk', 'houtp_Co-op apartment', 'houtp_House / apartment',
#        'houtp_Municipal apartment', 'houtp_Office apartment',
#        'houtp_Rented apartment', 'houtp_With parents',
#        'edutp_Higher education', 'edutp_Incomplete higher',
#        'edutp_Lower secondary', 'edutp_Secondary / secondary special',
#        'famtp_Civil marriage', 'famtp_Married', 'famtp_Separated',
#        'famtp_Single / not married', 'famtp_Widow'],
#       dtype='object')

# %%
new_data=new_data.loc[new_data['gp_inc_low']==1]
new_data['gp_inc_low'].count()
print(new_data['gp_inc_low'].value_counts())
# Out:
# 1.0    10955
# Name: gp_inc_low, dtype: int64

# %%
new_data=new_data.loc[new_data['Gender']==0]
new_data['Gender'].count()
print(new_data['Gender'].value_counts())
# Out:
# 0.0    8266
# Name: Gender, dtype: int64

# %%
new_data=new_data.loc[new_data['gp_Age_medium']==0]
new_data['gp_Age_medium'].count()
print(new_data['gp_Age_medium'].value_counts())
# Out:
# 0.0    5935
# Name: gp_Age_medium, dtype: int64

# %%
new_data=new_data.loc[new_data['email']==0]
new_data['email'].count()
print(new_data['email'].value_counts())
# Out:
# 0    5409
# Name: email, dtype: int64

# %%
new_data=new_data.loc[new_data['Reality']==1]
new_data['Reality'].count()
print(new_data['Reality'].value_counts())
# Out:
# 1.0    3378
# Name: Reality, dtype: int64

# %%
Y = new_data['target']
X = new_data[[ 'Gender', 'Car', 'Reality',
       'FLAG_MOBIL', 'wkphone', 'phone', 'email',  
         'ChldNo_0', 'ChldNo_1', 'ChldNo_2More',
       'gp_inc_high', 'gp_inc_low', 'gp_inc_medium', 'gp_Age_high',
       'gp_Age_highest', 'gp_Age_low', 'gp_Age_lowest', 'gp_Age_medium',
        'gp_worktm_high', 'gp_worktm_highest', 'gp_worktm_low',
       'gp_worktm_lowest', 'gp_worktm_medium', 'famsizegp_1', 'famsizegp_2',
       'famsizegp_3more', 'inctp_Commercial associate', 'inctp_State servant',
       'inctp_Working', 'occyp_Laborwk', 'occyp_Other', 'occyp_hightecwk',
       'occyp_officewk', 'houtp_Co-op apartment', 'houtp_House / apartment',
       'houtp_Municipal apartment', 'houtp_Office apartment',
       'houtp_Rented apartment', 'houtp_With parents',
       'edutp_Higher education', 'edutp_Incomplete higher',
       'edutp_Lower secondary', 'edutp_Secondary / secondary special',
       'famtp_Civil marriage', 'famtp_Married', 'famtp_Separated',
       'famtp_Single / not married', 'famtp_Widow'
      ]]
X.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 3378 entries, 20 to 30303
# Data columns (total 48 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   Gender                               3378 non-null   float64
#  1   Car                                  3378 non-null   float64
#  2   Reality                              3378 non-null   float64
#  3   FLAG_MOBIL                           3378 non-null   float64
#  4   wkphone                              3378 non-null   int64
#  5   phone                                3378 non-null   int64
#  6   email                                3378 non-null   int64
#  7   ChldNo_0                             3378 non-null   float64
#  8   ChldNo_1                             3378 non-null   float64
#  9   ChldNo_2More                         3378 non-null   float64
#  10  gp_inc_high                          3378 non-null   float64
#  11  gp_inc_low                           3378 non-null   float64
#  12  gp_inc_medium                        3378 non-null   float64
#  13  gp_Age_high                          3378 non-null   float64
#  14  gp_Age_highest                       3378 non-null   float64
#  15  gp_Age_low                           3378 non-null   float64
#  16  gp_Age_lowest                        3378 non-null   float64
#  17  gp_Age_medium                        3378 non-null   float64
#  18  gp_worktm_high                       3378 non-null   int64
#  19  gp_worktm_highest                    3378 non-null   int64
#  20  gp_worktm_low                        3378 non-null   int64
#  21  gp_worktm_lowest                     3378 non-null   int64
#  22  gp_worktm_medium                     3378 non-null   int64
#  23  famsizegp_1                          3378 non-null   int64
#  24  famsizegp_2                          3378 non-null   int64
#  25  famsizegp_3more                      3378 non-null   int64
#  26  inctp_Commercial associate           3378 non-null   int64
#  27  inctp_State servant                  3378 non-null   int64
#  28  inctp_Working                        3378 non-null   int64
#  29  occyp_Laborwk                        3378 non-null   int64
#  30  occyp_Other                          3378 non-null   int64
#  31  occyp_hightecwk                      3378 non-null   int64
#  32  occyp_officewk                       3378 non-null   int64
#  33  houtp_Co-op apartment                3378 non-null   int64
#  34  houtp_House / apartment              3378 non-null   int64
#  35  houtp_Municipal apartment            3378 non-null   int64
#  36  houtp_Office apartment               3378 non-null   int64
#  37  houtp_Rented apartment               3378 non-null   int64
#  38  houtp_With parents                   3378 non-null   int64
#  39  edutp_Higher education               3378 non-null   int64
#  40  edutp_Incomplete higher              3378 non-null   int64
#  41  edutp_Lower secondary                3378 non-null   int64
#  42  edutp_Secondary / secondary special  3378 non-null   int64
#  43  famtp_Civil marriage                 3378 non-null   int64
#  44  famtp_Married                        3378 non-null   int64
#  45  famtp_Separated                      3378 non-null   int64
#  46  famtp_Single / not married           3378 non-null   int64
#  47  famtp_Widow                          3378 non-null   int64
# dtypes: float64(15), int64(33)
# memory usage: 1.3 MB

# %%
import joblib
model = joblib.load("Completed_model6_2.joblib")

# %%
y_predict = model.predict(X)

print('Accuracy Score is {:.5}'.format(accuracy_score(Y, y_predict)))
print(pd.DataFrame(confusion_matrix(Y,y_predict)))

sns.set_style('white') 
class_names = ['0','1']
plot_confusion_matrix(confusion_matrix(Y,y_predict),
                      classes= class_names, normalize = True, 
                      title='Normalized Confusion Matrix: Logistic Regression')
# Out:
# Accuracy Score is 0.81883
#       0    1
# 0  2728  604
# 1     8   38
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-164-28ff1f7d353e> in <module>
#       6 sns.set_style('white')
#       7 class_names = ['0','1']
# ----> 8 plot_confusion_matrix(confusion_matrix(Y,y_predict),
#       9                       classes= class_names, normalize = True,
#      10                       title='Normalized Confusion Matrix: Logistic Regression')
#
# NameError: name 'plot_confusion_matrix' is not defined

# %%
new_data.to_csv('/Users/sdong/phd_doc/att/credit/subdata6.csv')

# %%
new_data = pd.read_csv("/Users/sdong/phd_doc/att/credit/all_data.csv", nrows=2425)
new_data=new_data.drop(['Unnamed: 0'], axis=1)
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2425 entries, 0 to 2424
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   2425 non-null   float64
#  1   Gender                               2425 non-null   float64
#  2   Car                                  2425 non-null   float64
#  3   Reality                              2425 non-null   float64
#  4   inc                                  2425 non-null   float64
#  5   DAYS_BIRTH                           2425 non-null   float64
#  6   DAYS_EMPLOYED                        2425 non-null   float64
#  7   FLAG_MOBIL                           2425 non-null   float64
#  8   wkphone                              2425 non-null   int64
#  9   phone                                2425 non-null   int64
#  10  email                                2425 non-null   int64
#  11  famsize                              2425 non-null   int64
#  12  begin_month                          2425 non-null   float64
#  13  dep_value                            2425 non-null   object
#  14  target                               2425 non-null   int64
#  15  ChldNo_0                             2425 non-null   float64
#  16  ChldNo_1                             2425 non-null   float64
#  17  ChldNo_2More                         2425 non-null   float64
#  18  gp_inc_high                          2425 non-null   float64
#  19  gp_inc_low                           2425 non-null   float64
#  20  gp_inc_medium                        2425 non-null   float64
#  21  Age                                  2425 non-null   float64
#  22  gp_Age_high                          2425 non-null   float64
#  23  gp_Age_highest                       2425 non-null   float64
#  24  gp_Age_low                           2425 non-null   float64
#  25  gp_Age_lowest                        2425 non-null   float64
#  26  gp_Age_medium                        2425 non-null   float64
#  27  worktm                               2425 non-null   float64
#  28  gp_worktm_high                       2425 non-null   int64
#  29  gp_worktm_highest                    2425 non-null   int64
#  30  gp_worktm_low                        2425 non-null   int64
#  31  gp_worktm_lowest                     2425 non-null   int64
#  32  gp_worktm_medium                     2425 non-null   int64
#  33  famsizegp_1                          2425 non-null   int64
#  34  famsizegp_2                          2425 non-null   int64
#  35  famsizegp_3more                      2425 non-null   int64
#  36  inctp_Commercial associate           2425 non-null   int64
#  37  inctp_State servant                  2425 non-null   int64
#  38  inctp_Working                        2425 non-null   int64
#  39  occyp_Laborwk                        2425 non-null   int64
#  40  occyp_Other                          2425 non-null   int64
#  41  occyp_hightecwk                      2425 non-null   int64
#  42  occyp_officewk                       2425 non-null   int64
#  43  houtp_Co-op apartment                2425 non-null   int64
#  44  houtp_House / apartment              2425 non-null   int64
#  45  houtp_Municipal apartment            2425 non-null   int64
#  46  houtp_Office apartment               2425 non-null   int64
#  47  houtp_Rented apartment               2425 non-null   int64
#  48  houtp_With parents                   2425 non-null   int64
#  49  edutp_Higher education               2425 non-null   int64
#  50  edutp_Incomplete higher              2425 non-null   int64
#  51  edutp_Lower secondary                2425 non-null   int64
#  52  edutp_Secondary / secondary special  2425 non-null   int64
#  53  famtp_Civil marriage                 2425 non-null   int64
#  54  famtp_Married                        2425 non-null   int64
#  55  famtp_Separated                      2425 non-null   int64
#  56  famtp_Single / not married           2425 non-null   int64
#  57  famtp_Widow                          2425 non-null   int64
# dtypes: float64(22), int64(35), object(1)
# memory usage: 1.1+ MB

# %%
new_data2 = pd.read_csv("/Users/sdong/phd_doc/att/credit/subdata6.csv")
new_data2=new_data2.drop(['Unnamed: 0'], axis=1)
new_data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3378 entries, 0 to 3377
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   3378 non-null   float64
#  1   Gender                               3378 non-null   float64
#  2   Car                                  3378 non-null   float64
#  3   Reality                              3378 non-null   float64
#  4   inc                                  3378 non-null   float64
#  5   DAYS_BIRTH                           3378 non-null   float64
#  6   DAYS_EMPLOYED                        3378 non-null   float64
#  7   FLAG_MOBIL                           3378 non-null   float64
#  8   wkphone                              3378 non-null   int64
#  9   phone                                3378 non-null   int64
#  10  email                                3378 non-null   int64
#  11  famsize                              3378 non-null   int64
#  12  begin_month                          3378 non-null   float64
#  13  dep_value                            3378 non-null   object
#  14  target                               3378 non-null   int64
#  15  ChldNo_0                             3378 non-null   float64
#  16  ChldNo_1                             3378 non-null   float64
#  17  ChldNo_2More                         3378 non-null   float64
#  18  gp_inc_high                          3378 non-null   float64
#  19  gp_inc_low                           3378 non-null   float64
#  20  gp_inc_medium                        3378 non-null   float64
#  21  Age                                  3378 non-null   float64
#  22  gp_Age_high                          3378 non-null   float64
#  23  gp_Age_highest                       3378 non-null   float64
#  24  gp_Age_low                           3378 non-null   float64
#  25  gp_Age_lowest                        3378 non-null   float64
#  26  gp_Age_medium                        3378 non-null   float64
#  27  worktm                               3378 non-null   float64
#  28  gp_worktm_high                       3378 non-null   int64
#  29  gp_worktm_highest                    3378 non-null   int64
#  30  gp_worktm_low                        3378 non-null   int64
#  31  gp_worktm_lowest                     3378 non-null   int64
#  32  gp_worktm_medium                     3378 non-null   int64
#  33  famsizegp_1                          3378 non-null   int64
#  34  famsizegp_2                          3378 non-null   int64
#  35  famsizegp_3more                      3378 non-null   int64
#  36  inctp_Commercial associate           3378 non-null   int64
#  37  inctp_State servant                  3378 non-null   int64
#  38  inctp_Working                        3378 non-null   int64
#  39  occyp_Laborwk                        3378 non-null   int64
#  40  occyp_Other                          3378 non-null   int64
#  41  occyp_hightecwk                      3378 non-null   int64
#  42  occyp_officewk                       3378 non-null   int64
#  43  houtp_Co-op apartment                3378 non-null   int64
#  44  houtp_House / apartment              3378 non-null   int64
#  45  houtp_Municipal apartment            3378 non-null   int64
#  46  houtp_Office apartment               3378 non-null   int64
#  47  houtp_Rented apartment               3378 non-null   int64
#  48  houtp_With parents                   3378 non-null   int64
#  49  edutp_Higher education               3378 non-null   int64
#  50  edutp_Incomplete higher              3378 non-null   int64
#  51  edutp_Lower secondary                3378 non-null   int64
#  52  edutp_Secondary / secondary special  3378 non-null   int64
#  53  famtp_Civil marriage                 3378 non-null   int64
#  54  famtp_Married                        3378 non-null   int64
#  55  famtp_Separated                      3378 non-null   int64
#  56  famtp_Single / not married           3378 non-null   int64
#  57  famtp_Widow                          3378 non-null   int64
# dtypes: float64(22), int64(35), object(1)
# memory usage: 1.5+ MB

# %%
# 现将表构成list，然后在作为concat的输入
frames = [new_data, new_data2]
result = pd.concat(frames)

# %%
result.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 5803 entries, 0 to 3377
# Data columns (total 58 columns):
#  #   Column                               Non-Null Count  Dtype
# ---  ------                               --------------  -----
#  0   ID                                   5803 non-null   float64
#  1   Gender                               5803 non-null   float64
#  2   Car                                  5803 non-null   float64
#  3   Reality                              5803 non-null   float64
#  4   inc                                  5803 non-null   float64
#  5   DAYS_BIRTH                           5803 non-null   float64
#  6   DAYS_EMPLOYED                        5803 non-null   float64
#  7   FLAG_MOBIL                           5803 non-null   float64
#  8   wkphone                              5803 non-null   int64
#  9   phone                                5803 non-null   int64
#  10  email                                5803 non-null   int64
#  11  famsize                              5803 non-null   int64
#  12  begin_month                          5803 non-null   float64
#  13  dep_value                            5803 non-null   object
#  14  target                               5803 non-null   int64
#  15  ChldNo_0                             5803 non-null   float64
#  16  ChldNo_1                             5803 non-null   float64
#  17  ChldNo_2More                         5803 non-null   float64
#  18  gp_inc_high                          5803 non-null   float64
#  19  gp_inc_low                           5803 non-null   float64
#  20  gp_inc_medium                        5803 non-null   float64
#  21  Age                                  5803 non-null   float64
#  22  gp_Age_high                          5803 non-null   float64
#  23  gp_Age_highest                       5803 non-null   float64
#  24  gp_Age_low                           5803 non-null   float64
#  25  gp_Age_lowest                        5803 non-null   float64
#  26  gp_Age_medium                        5803 non-null   float64
#  27  worktm                               5803 non-null   float64
#  28  gp_worktm_high                       5803 non-null   int64
#  29  gp_worktm_highest                    5803 non-null   int64
#  30  gp_worktm_low                        5803 non-null   int64
#  31  gp_worktm_lowest                     5803 non-null   int64
#  32  gp_worktm_medium                     5803 non-null   int64
#  33  famsizegp_1                          5803 non-null   int64
#  34  famsizegp_2                          5803 non-null   int64
#  35  famsizegp_3more                      5803 non-null   int64
#  36  inctp_Commercial associate           5803 non-null   int64
#  37  inctp_State servant                  5803 non-null   int64
#  38  inctp_Working                        5803 non-null   int64
#  39  occyp_Laborwk                        5803 non-null   int64
#  40  occyp_Other                          5803 non-null   int64
#  41  occyp_hightecwk                      5803 non-null   int64
#  42  occyp_officewk                       5803 non-null   int64
#  43  houtp_Co-op apartment                5803 non-null   int64
#  44  houtp_House / apartment              5803 non-null   int64
#  45  houtp_Municipal apartment            5803 non-null   int64
#  46  houtp_Office apartment               5803 non-null   int64
#  47  houtp_Rented apartment               5803 non-null   int64
#  48  houtp_With parents                   5803 non-null   int64
#  49  edutp_Higher education               5803 non-null   int64
#  50  edutp_Incomplete higher              5803 non-null   int64
#  51  edutp_Lower secondary                5803 non-null   int64
#  52  edutp_Secondary / secondary special  5803 non-null   int64
#  53  famtp_Civil marriage                 5803 non-null   int64
#  54  famtp_Married                        5803 non-null   int64
#  55  famtp_Separated                      5803 non-null   int64
#  56  famtp_Single / not married           5803 non-null   int64
#  57  famtp_Widow                          5803 non-null   int64
# dtypes: float64(22), int64(35), object(1)
# memory usage: 2.6+ MB

# %%
Y = result['target']
X = result[[ 'Gender', 'Car', 'Reality',
       'FLAG_MOBIL', 'wkphone', 'phone', 'email',  
         'ChldNo_0', 'ChldNo_1', 'ChldNo_2More',
       'gp_inc_high', 'gp_inc_low', 'gp_inc_medium', 'gp_Age_high',
       'gp_Age_highest', 'gp_Age_low', 'gp_Age_lowest', 'gp_Age_medium',
        'gp_worktm_high', 'gp_worktm_highest', 'gp_worktm_low',
       'gp_worktm_lowest', 'gp_worktm_medium', 'famsizegp_1', 'famsizegp_2',
       'famsizegp_3more', 'inctp_Commercial associate', 'inctp_State servant',
       'inctp_Working', 'occyp_Laborwk', 'occyp_Other', 'occyp_hightecwk',
       'occyp_officewk', 'houtp_Co-op apartment', 'houtp_House / apartment',
       'houtp_Municipal apartment', 'houtp_Office apartment',
       'houtp_Rented apartment', 'houtp_With parents',
       'edutp_Higher education', 'edutp_Incomplete higher',
       'edutp_Lower secondary', 'edutp_Secondary / secondary special',
       'famtp_Civil marriage', 'famtp_Married', 'famtp_Separated',
       'famtp_Single / not married', 'famtp_Widow'
      ]]

from imblearn.over_sampling import SMOTE
Y = Y.astype('int')
oversample = SMOTE()
X_balance,Y_balance = oversample.fit_resample(X,Y)
X_balance = pd.DataFrame(X_balance, columns = X.columns)

X_train, X_test, y_train, y_test = train_test_split(X_balance,Y_balance, 
                                                    stratify=Y_balance, test_size=0.3,
                                                    random_state = 10086)

# %%
model = DecisionTreeClassifier(max_depth=8,
                               min_samples_split=10,
                               random_state=0)
model1=model.fit(X_train, y_train)
y_predict = model.predict(X_test)

print('Accuracy Score is {:.5}'.format(accuracy_score(y_test, y_predict)))
print(pd.DataFrame(confusion_matrix(y_test,y_predict)))

sns.set_style('white') 
class_names = ['0','1']
plot_confusion_matrix(confusion_matrix(y_test,y_predict),
                      classes=class_names, normalize = True, 
                      title='Normalized Confusion Matrix: CART')
# Out:
# Accuracy Score is 0.93496
#       0     1
# 0  1502   220
# 1     4  1718
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-152-eaff44e8b847> in <module>
#      10 sns.set_style('white')
#      11 class_names = ['0','1']
# ---> 12 plot_confusion_matrix(confusion_matrix(y_test,y_predict),
#      13                       classes=class_names, normalize = True,
#      14                       title='Normalized Confusion Matrix: CART')
#
# NameError: name 'plot_confusion_matrix' is not defined

# %%
result.to_csv('/Users/sdong/phd_doc/att/credit/subdata6_2.csv')

# %%
from sklearn import model_selection, datasets
from sklearn.tree import DecisionTreeClassifier
import joblib
import pickle
    
filename = "Completed_model6_2.joblib"
joblib.dump(model1, filename)
# Out:
# ['Completed_model6_2.joblib']

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import cross_val_score
from sklearn import tree
import pydotplus


dot_data=tree.export_graphviz(model1, out_file='tree3.dot')
score = cross_val_score(model1, X_train, y_train, cv=10)
print (score)
from subprocess import check_call
check_call(['dot','-Tpng','tree3.dot','-o','tree3.png'])
# Out:
# [0.8875     0.86770833 0.86979167 0.871875   0.86770833 0.86666667
#  0.86666667 0.88112617 0.88738269 0.8738269 ]
# 0

# %%
new_data = pd.read_csv("/Users/sdong/phd_doc/att/credit/all_data.csv")
new_data.info()
new_data.isnull().sum().sort_values(ascending=False)
new_data=new_data.drop(['Unnamed: 0'], axis=1)
new_data.columns
